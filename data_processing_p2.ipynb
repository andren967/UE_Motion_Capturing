# %%
#Import of used Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
p4 = pd.read_csv("../UE_Motion_Capture/data_export/walking_music_P2_pos.tsv",delimiter="\t",usecols=["RHeel_pos_Z","LHeel_pos_Z"])

# %%
plt.boxplot(p4["RHeel_pos_Z"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2208cff55d0>,
#   <matplotlib.lines.Line2D at 0x2208cff5e50>],
#  'caps': [<matplotlib.lines.Line2D at 0x2208cff67d0>,
#   <matplotlib.lines.Line2D at 0x2208cff7250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2208cff4bd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2208cff7ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2208d800390>],
#  'means': []}

# %%
#Calculation of right foot steps
Rsteps = []
frame = 0
bValley = False
for index, values in p4.iterrows():
    RValue = values["RHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if RValue < 70:
        bValley = False
        for i in range(1,80):
            if frame == 161:
                breakpoint()
            before = p4.loc[frame-i,"RHeel_pos_Z"]
            next = p4.loc[frame+i,"RHeel_pos_Z"]
            if (RValue <= before) and (RValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("R - ", frame, ": ", RValue)
            Rsteps.append([frame,RValue])
    frame += 1
# Out:
# R -  211 :  44.167
# R -  324 :  43.986
# R -  426 :  40.939
# R -  532 :  38.849
# R -  640 :  44.114
# R -  746 :  48.9
# R -  853 :  49.998
# R -  963 :  48.816
# R -  1073 :  47.379
# R -  1180 :  40.178
# R -  1285 :  43.772
# R -  1394 :  41.674
# R -  1502 :  39.124
# R -  1616 :  43.925
# R -  1720 :  48.003
# R -  1828 :  51.07
# R -  1936 :  50.35
# R -  2048 :  49.634
# R -  2159 :  43.215
# R -  2268 :  42.095
# R -  2377 :  42.416
# R -  2486 :  36.909
# R -  2595 :  42.854
# R -  2704 :  47.926
# R -  2812 :  51.33
# R -  2925 :  49.613
# R -  3038 :  49.613
# R -  3151 :  46.081
# R -  3263 :  40.297
# R -  3375 :  42.942
# R -  3487 :  40.13
# R -  3600 :  41.797
# R -  3710 :  46.387
# R -  3824 :  49.905
# R -  3936 :  51.724
# R -  4050 :  50.167
# R -  4166 :  46.93
# R -  4280 :  42.73
# R -  4394 :  44.074
# R -  4508 :  41.913
# R -  4622 :  39.072
# R -  4741 :  44.594
# R -  4853 :  48.375
# R -  4959 :  50.443
# R -  5060 :  48.626
# R -  5165 :  49.1
# R -  5271 :  43.534
# R -  5376 :  44.005
# R -  5489 :  44.835
# R -  5603 :  45.632
# R -  5708 :  45.765
# R -  5823 :  48.416
# R -  5931 :  51.915
# R -  6030 :  54.27
# R -  6134 :  49.94
# R -  6245 :  50.876
# R -  6356 :  46.479
# R -  6464 :  40.53
# R -  6577 :  47.541
# R -  6689 :  46.412
# R -  6808 :  44.298
# R -  6925 :  49.978
# R -  7028 :  49.782
# R -  7153 :  53.142
# R -  7271 :  54.359
# R -  7389 :  50.938
# R -  7510 :  51.252
# R -  7626 :  43.134
# R -  7743 :  42.527
# R -  7865 :  42.768
# R -  7996 :  39.522
# R -  8119 :  44.647
# R -  8244 :  48.446
# R -  8366 :  52.119
# R -  8488 :  50.69
# R -  8603 :  50.771
# R -  8720 :  44.867
# R -  8842 :  40.042
# R -  8966 :  43.941
# R -  9090 :  39.713
# R -  9213 :  41.41
# R -  9327 :  45.911
# R -  9443 :  49.734
# R -  9556 :  50.152
# R -  9676 :  49.736
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 9858 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p2.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>     breakpoint()
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> before = p4.loc[frame-i,"RHeel_pos_Z"]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> next = p4.loc[frame+i,"RHeel_pos_Z"]
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> if (RValue <= before) and (RValue <= next):
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>     bValley = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4015, in DataFrame._get_value(self, index, col, takeable)
#    4009 engine = self.index._engine
#    4011 if not isinstance(self.index, MultiIndex):
#    4012     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4013     #  results if our categories are integers that dont match our codes
#    4014     # IntervalIndex: IntervalTree has no get_loc
# -> 4015     row = self.index.get_loc(index)
#    4016     return series._values[row]
#    4018 # For MultiIndex going through engine effectively restricts us to
#    4019 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: 9858

# %%
#Calculation of left foot steps
LSteps = []
frame = 0
for index, values in p4.iterrows():
    LValue = values["LHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if LValue < 70:
        for i in range(1,80):
            before = p4.loc[frame-i,"LHeel_pos_Z"]
            next = p4.loc[frame+i,"LHeel_pos_Z"]
            if (LValue <= before) and (LValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("L - ", frame, ": ", LValue)
            LSteps.append([frame,LValue])
    frame += 1
# Out:
# L -  161 :  54.7
# L -  270 :  33.289
# L -  375 :  35.756
# L -  479 :  32.733
# L -  585 :  36.802
# L -  692 :  42.052
# L -  799 :  44.831
# L -  908 :  42.329
# L -  1017 :  42.739
# L -  1125 :  38.036
# L -  1231 :  33.344
# L -  1338 :  37.973
# L -  1446 :  33.63
# L -  1557 :  35.497
# L -  1666 :  41.316
# L -  1773 :  45.476
# L -  1881 :  41.791
# L -  1992 :  43.499
# L -  2103 :  41.16
# L -  2214 :  36.677
# L -  2322 :  37.581
# L -  2431 :  34.512
# L -  2539 :  33.618
# L -  2649 :  41.8
# L -  2756 :  45.562
# L -  2867 :  44.5
# L -  2981 :  42.047
# L -  3094 :  42.205
# L -  3206 :  37.545
# L -  3317 :  37.298
# L -  3430 :  35.406
# L -  3543 :  32.314
# L -  3654 :  38.893
# L -  3766 :  43.122
# L -  3881 :  46.088
# L -  3994 :  42.206
# L -  4108 :  42.481
# L -  4222 :  39.838
# L -  4336 :  32.566
# L -  4452 :  36.841
# L -  4564 :  33.544
# L -  4680 :  36.714
# L -  4797 :  42.028
# L -  4905 :  46.336
# L -  5009 :  43.143
# L -  5113 :  42.865
# L -  5217 :  40.228
# L -  5322 :  33.876
# L -  5429 :  38.175
# L -  5545 :  36.154
# L -  5654 :  36.551
# L -  5763 :  39.984
# L -  5875 :  45.169
# L -  5978 :  47.76
# L -  6081 :  43.411
# L -  6184 :  45.635
# L -  6300 :  41.368
# L -  6409 :  37.155
# L -  6520 :  39.036
# L -  6633 :  38.857
# L -  6746 :  34.855
# L -  6871 :  38.341
# L -  6976 :  45.469
# L -  7089 :  44.812
# L -  7210 :  46.126
# L -  7328 :  43.671
# L -  7447 :  43.074
# L -  7566 :  40.365
# L -  7682 :  35.517
# L -  7801 :  37.631
# L -  7929 :  33.822
# L -  8056 :  34.306
# L -  8180 :  40.891
# L -  8301 :  44.167
# L -  8428 :  42.548
# L -  8545 :  45.089
# L -  8661 :  42.835
# L -  8781 :  37.717
# L -  8902 :  38.37
# L -  9025 :  35.68
# L -  9151 :  32.138
# L -  9268 :  39.946
# L -  9383 :  43.818
# L -  9498 :  45.328
# L -  9614 :  42.458
# L -  9733 :  44.674

# %%
#Combination of steps
steps = LSteps + Rsteps
steps.sort()

# %%
steps = pd.DataFrame(steps)
steps
# Out:
#         0       1
# 0     161  54.700
# 1     211  44.167
# 2     270  33.289
# 3     324  43.986
# 4     375  35.756
# ..    ...     ...
# 166  9498  45.328
# 167  9556  50.152
# 168  9614  42.458
# 169  9676  49.736
# 170  9733  44.674
#
# [171 rows x 2 columns]

# %%
m1 = pd.read_csv("../UE_Motion_Capture/music/export_big_john.txt",delimiter="\t", header=None)
m2 = pd.read_csv("../UE_Motion_Capture/music/export_berlioz.txt",delimiter="\t", header=None)
m3 = pd.read_csv("../UE_Motion_Capture/music/export_wombats.txt",delimiter="\t", header=None)

# %%
#delete first row
m1 = m1.drop(index=0)
m2 = m2.drop(index=0)
m3 = m3.drop(index=0)

# %%
start_music = pd.read_csv("../UE_Motion_Capture/start_of_music.csv",delimiter="\t", header=None)

# %%
start_music[start_music[0]=='P2_M2'][1].item()
# Out:
# 5200.0

# %%
#Update TIme Values, to frames, to starting_time 
m1[0] = (m1[0]*100)+start_music[start_music[0]=='P2_M1'][1].item()
m2[0] = (m2[0]*100)+start_music[start_music[0]=='P2_M2'][1].item()
m3[0] = (m3[0]*100)+start_music[start_music[0]=='P2_M3'][1].item()

# %%
m2
# Out:
#               0           1
# 1   5385.179138  80.7495BPM
# 2   5459.482993  80.7495BPM
# 3   5533.786848  80.7495BPM
# 4   5608.090703  80.7495BPM
# 5   5684.716553  78.3026BPM
# 6   5760.181406  79.5072BPM
# 7   5835.646258  79.5072BPM
# 8   5911.111111  79.5072BPM
# 9   5984.253968  82.0313BPM
# 10  6058.557823  80.7495BPM
# 11  6135.183673  78.3026BPM
# 12  6210.648526  79.5072BPM
# 13  6283.791383  82.0313BPM
# 14  6358.095238  80.7495BPM
# 15  6432.399093  80.7495BPM
# 16  6506.702948  80.7495BPM
# 17  6581.006803  80.7495BPM
# 18  6655.310658  80.7495BPM
# 19  6729.614513  80.7495BPM
# 20  6803.918367  80.7495BPM
# 21  6880.544218  78.3026BPM
# 22  6958.331066  77.1339BPM

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.vlines(m2[0],0,500)
plt.vlines(m3[0],0,500)
plt.ylim([30, 70])
plt.xlim([0, 9800])
# Out:
# (0.0, 9800.0)

# %%
start = m1[0].min()
end = m1[0].max()

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 107.86429557568752

# %%
#ersten 5 Sekunden
start = m1[0].min()
end = m1[0].min()+500

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 108.0

# %% [markdown]
# # P2 - M1

# %%
m1_start = m1[0].min()
m1_end = m1[0].max()
print(m1_start)
print(m1_end)
# Out:
# 2750.3492063
# 4641.6145125

# %%
beats_in_m1_range = m1[(m1[0]>=m1_start) & (m1[0]<=m1_end)][0] 
steps_in_m1_range = steps.loc[(steps[0] >= m1_start) & (steps[0] <= m1_end)][0]

# %%
steps_in_m1_range.count()
# Out:
# 34

# %%
beats_in_m1_range.count()
# Out:
# 29

# %%
(29/20)*60
# Out:
# 87.0

# %%
(34/20)*60
# Out:
# 102.0

# %%
beats_in_m1_range
# Out:
# 1     2750.349206
# 2     2818.848073
# 3     2887.346939
# 4     2955.845805
# 5     3022.022676
# 6     3089.360544
# 7     3156.698413
# 8     3226.358277
# 9     3294.857143
# 10    3363.356009
# 11    3431.854875
# 12    3498.031746
# 13    3565.369614
# 14    3632.707483
# 15    3697.723356
# 16    3762.739229
# 17    3831.238095
# 18    3900.897959
# 19    3969.396825
# 20    4037.895692
# 21    4106.394558
# 22    4172.571429
# 23    4237.587302
# 24    4303.764172
# 25    4372.263038
# 26    4439.600907
# 27    4506.938775
# 28    4574.276644
# 29    4641.614513
# Name: 0, dtype: float64

# %%
#all MUSIC M1
beats_in_m1_range.count()/((beats_in_m1_range.max()-beats_in_m1_range.min())/100)*60
# Out:
# 92.00189916749818

# %%
steps_in_m1_range.count()
# Out:
# 34

# %%
steps_in_m1_range.max()-steps_in_m1_range.min()
# Out:
# 1866

# %%
(34/(1866/100))*60
# Out:
# 109.32475884244373

# %%
#all WALKING M1
steps_in_m1_range.count()/((steps_in_m1_range.max()-steps_in_m1_range.min())/100)*60
# Out:
# 109.32475884244373

# %%
after3W = steps_in_m1_range[steps_in_m1_range >= steps_in_m1_range.min()+300]

# %%
after3M = beats_in_m1_range[beats_in_m1_range >= beats_in_m1_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100)*60
# Out:
# 109.94764397905759

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100)*60
# Out:
# 92.7683246045788

# %%
from statistics import mean
mean(abs(x - y) for x, y in zip(beats_in_m1_range, steps_in_m1_range))
# Out:
# 154.73140980344823

# %%
from sklearn.metrics import mean_squared_error 
  
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(beats_in_m1_range,steps_in_m1_range)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p2.ipynb Cell 35 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.metrics import mean_squared_error
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> # Calculation of Mean Squared Error (MSE)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p2.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> mean_squared_error(beats_in_m1_range,steps_in_m1_range)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [29, 34]

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.ylim([30, 70])
plt.xlim([m1_start-20, m1_end+20])
# Out:
# (2730.3492063, 4661.6145125)

# %% [markdown]
# # P2 - M2

# %%
m2_start = m2[0].min()
m2_end = m2[0].max()
print(m2_start)
print(m2_end)
# Out:
# 5385.1791383
# 6958.3310658

# %%
beats_in_m2_range = m2[(m2[0]>=m2_start) & (m2[0]<=m2_end)][0] 
steps_in_m2_range = steps.loc[(steps[0] >= m2_start) & (steps[0] <= m2_end)][0]

# %%
#all MUSIC M1
beats_in_m2_range.count()/((beats_in_m2_range.max()-beats_in_m2_range.min())/100/60)
# Out:
# 83.90797970147102

# %%
#all WALKING M1
steps_in_m2_range.count()/((steps_in_m2_range.max()-steps_in_m2_range.min())/100/60)
# Out:
# 112.29946524064171

# %%
after3W = steps_in_m2_range[steps_in_m2_range >= steps_in_m2_range.min()+300]

# %%
after3M = beats_in_m2_range[beats_in_m2_range >= beats_in_m2_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 113.59724612736662

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 85.1312681660429

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
plt.vlines(m2[0],0,500)
plt.ylim([30, 70])
plt.xlim([m2_start-20, m2_end+20])
# Out:
# (5365.1791383, 6978.3310658)

# %% [markdown]
# # P2 - M3

# %%
m3_start = m3[0].min()
m3_end = m3[0].max()
print(m3_start)
print(m3_end)
# Out:
# 7658.4761905
# 9601.9863946

# %%
beats_in_m3_range = m3[(m3[0]>=m3_start) & (m3[0]<=m3_end)][0] 
steps_in_m3_range = steps.loc[(steps[0] >= m3_start) & (steps[0] <= m3_end)][0]

# %%
#all MUSIC M1
beats_in_m3_range.count()/((beats_in_m3_range.max()-beats_in_m3_range.min())/100/60)
# Out:
# 95.70312499909551

# %%
#all WALKING M1
steps_in_m3_range.count()/((steps_in_m3_range.max()-steps_in_m3_range.min())/100/60)
# Out:
# 102.4546424759872

# %%
after3W = steps_in_m3_range[steps_in_m3_range >= steps_in_m3_range.min()+300]

# %%
after3M = beats_in_m3_range[beats_in_m3_range >= beats_in_m3_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 103.84615384615384

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 96.38966104748079

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m3[0],0,500)
plt.ylim([30, 70])
plt.xlim([m3_start-20, m3_end+20])
# Out:
# (7638.4761905, 9621.9863946)
