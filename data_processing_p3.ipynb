# %%
#Import of used Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
p4 = pd.read_csv("../UE_Motion_Capture/data_export/walking_music_P3_pos.tsv",delimiter="\t",usecols=["RHeel_pos_Z","LHeel_pos_Z"])

# %%
plt.boxplot(p4["RHeel_pos_Z"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28f31718bd0>,
#   <matplotlib.lines.Line2D at 0x28f31719a10>],
#  'caps': [<matplotlib.lines.Line2D at 0x28f3171a650>,
#   <matplotlib.lines.Line2D at 0x28f3171b350>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28f317083d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x28f3171be50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28f31720a50>],
#  'means': []}

# %%
#Calculation of right foot steps
Rsteps = []
frame = 0
bValley = False
for index, values in p4.iterrows():
    RValue = values["RHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if RValue < 70:
        bValley = False
        for i in range(1,80):
            if frame == 161:
                breakpoint()
            before = p4.loc[frame-i,"RHeel_pos_Z"]
            next = p4.loc[frame+i,"RHeel_pos_Z"]
            if (RValue <= before) and (RValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("R - ", frame, ": ", RValue)
            Rsteps.append([frame,RValue])
    frame += 1
# Out:
# R -  181 :  13.665
# R -  305 :  16.286
# R -  423 :  14.16
# R -  539 :  10.098
# R -  654 :  16.772
# R -  769 :  20.931
# R -  884 :  21.709
# R -  1001 :  20.285
# R -  1118 :  20.046
# R -  1231 :  15.971
# R -  1346 :  13.976
# R -  1462 :  13.739
# R -  1576 :  12.034
# R -  1692 :  14.0
# R -  1810 :  18.47
# R -  1925 :  22.723
# R -  2041 :  20.547
# R -  2157 :  21.362
# R -  2274 :  17.213
# R -  2391 :  13.497
# R -  2508 :  15.486
# R -  2627 :  11.882
# R -  2758 :  10.3
# R -  2898 :  15.718
# R -  3050 :  21.083
# R -  3187 :  19.262
# R -  3323 :  20.941
# R -  3453 :  19.428
# R -  3585 :  14.042
# R -  3717 :  14.432
# R -  3852 :  13.074
# R -  3983 :  10.196
# R -  4121 :  12.655
# R -  4259 :  19.015
# R -  4395 :  21.909
# R -  4532 :  20.286
# R -  4666 :  20.626
# R -  4791 :  18.173
# R -  4910 :  14.591
# R -  5030 :  16.158
# R -  5151 :  13.631
# R -  5269 :  10.272
# R -  5388 :  14.939
# R -  5519 :  20.1
# R -  5637 :  22.282
# R -  5754 :  20.677
# R -  5888 :  19.98
# R -  6016 :  15.752
# R -  6136 :  13.326
# R -  6254 :  15.696
# R -  6379 :  12.779
# R -  6505 :  11.532
# R -  6626 :  16.901
# R -  6750 :  20.378
# R -  6873 :  20.981
# R -  7003 :  21.075
# R -  7125 :  20.451
# R -  7246 :  14.792
# R -  7362 :  15.176
# R -  7487 :  14.238
# R -  7597 :  11.864
# R -  7709 :  12.532
# R -  7841 :  17.608
# R -  7970 :  22.74
# R -  8091 :  19.243
# R -  8222 :  20.249
# R -  8348 :  14.697
# R -  8476 :  13.976
# R -  8609 :  12.1
# R -  8739 :  10.082
# R -  8865 :  14.503
# R -  8997 :  18.371
# R -  9129 :  22.095
# R -  9264 :  20.221
# R -  9389 :  18.851
# R -  9516 :  13.568
# R -  9646 :  15.444
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 9777 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p3.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>     breakpoint()
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> before = p4.loc[frame-i,"RHeel_pos_Z"]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> next = p4.loc[frame+i,"RHeel_pos_Z"]
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> if (RValue <= before) and (RValue <= next):
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>     bValley = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4015, in DataFrame._get_value(self, index, col, takeable)
#    4009 engine = self.index._engine
#    4011 if not isinstance(self.index, MultiIndex):
#    4012     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4013     #  results if our categories are integers that dont match our codes
#    4014     # IntervalIndex: IntervalTree has no get_loc
# -> 4015     row = self.index.get_loc(index)
#    4016     return series._values[row]
#    4018 # For MultiIndex going through engine effectively restricts us to
#    4019 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: 9777

# %%
#Calculation of left foot steps
LSteps = []
frame = 0
for index, values in p4.iterrows():
    LValue = values["LHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if LValue < 70:
        for i in range(1,80):
            before = p4.loc[frame-i,"LHeel_pos_Z"]
            next = p4.loc[frame+i,"LHeel_pos_Z"]
            if (LValue <= before) and (LValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("L - ", frame, ": ", LValue)
            LSteps.append([frame,LValue])
    frame += 1
# Out:
# L -  153 :  21.937
# L -  244 :  9.77
# L -  362 :  11.777
# L -  480 :  10.295
# L -  592 :  12.275
# L -  709 :  19.734
# L -  823 :  20.602
# L -  942 :  19.909
# L -  1057 :  18.773
# L -  1171 :  15.767
# L -  1285 :  11.528
# L -  1403 :  13.202
# L -  1517 :  12.208
# L -  1632 :  9.105
# L -  1750 :  17.601
# L -  1866 :  19.622
# L -  1984 :  20.85
# L -  2097 :  21.669
# L -  2213 :  18.504
# L -  2332 :  14.591
# L -  2447 :  11.257
# L -  2564 :  12.415
# L -  2691 :  9.248
# L -  2827 :  14.486
# L -  2974 :  18.5
# L -  3117 :  19.677
# L -  3252 :  21.074
# L -  3385 :  19.192
# L -  3519 :  15.894
# L -  3649 :  10.362
# L -  3783 :  13.629
# L -  3919 :  10.545
# L -  4052 :  9.949
# L -  4191 :  18.143
# L -  4326 :  19.179
# L -  4461 :  20.69
# L -  4597 :  20.736
# L -  4726 :  17.985
# L -  4848 :  15.003
# L -  4967 :  11.381
# L -  5088 :  12.6
# L -  5208 :  10.097
# L -  5329 :  12.791
# L -  5452 :  18.27
# L -  5576 :  20.684
# L -  5695 :  20.899
# L -  5817 :  20.851
# L -  5949 :  16.967
# L -  6074 :  14.212
# L -  6193 :  11.614
# L -  6315 :  12.809
# L -  6439 :  8.42
# L -  6561 :  13.228
# L -  6685 :  19.727
# L -  6811 :  19.548
# L -  6936 :  19.882
# L -  7062 :  19.037
# L -  7188 :  16.159
# L -  7306 :  10.428
# L -  7425 :  12.641
# L -  7543 :  11.869
# L -  7650 :  10.286
# L -  7776 :  16.852
# L -  7905 :  18.498
# L -  8028 :  20.279
# L -  8155 :  17.65
# L -  8285 :  16.672
# L -  8412 :  11.621
# L -  8540 :  10.681
# L -  8672 :  8.094
# L -  8801 :  8.854
# L -  8931 :  16.547
# L -  9064 :  18.359
# L -  9196 :  19.719
# L -  9323 :  17.049
# L -  9450 :  14.226
# L -  9581 :  8.529
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 9777 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p3.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> for i in range(1,80):
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a>     before = p4.loc[frame-i,"LHeel_pos_Z"]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a>     next = p4.loc[frame+i,"LHeel_pos_Z"]
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a>     if (LValue <= before) and (LValue <= next):
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a>         bValley = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4015, in DataFrame._get_value(self, index, col, takeable)
#    4009 engine = self.index._engine
#    4011 if not isinstance(self.index, MultiIndex):
#    4012     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4013     #  results if our categories are integers that dont match our codes
#    4014     # IntervalIndex: IntervalTree has no get_loc
# -> 4015     row = self.index.get_loc(index)
#    4016     return series._values[row]
#    4018 # For MultiIndex going through engine effectively restricts us to
#    4019 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: 9777

# %%
#Combination of steps
steps = LSteps + Rsteps
steps.sort()

# %%
steps = pd.DataFrame(steps)
steps
# Out:
#         0       1
# 0     153  21.937
# 1     181  13.665
# 2     244   9.770
# 3     305  16.286
# 4     362  11.777
# ..    ...     ...
# 149  9389  18.851
# 150  9450  14.226
# 151  9516  13.568
# 152  9581   8.529
# 153  9646  15.444
#
# [154 rows x 2 columns]

# %%
m1 = pd.read_csv("../UE_Motion_Capture/music/export_big_john.txt",delimiter="\t", header=None)
m2 = pd.read_csv("../UE_Motion_Capture/music/export_berlioz.txt",delimiter="\t", header=None)
m3 = pd.read_csv("../UE_Motion_Capture/music/export_wombats.txt",delimiter="\t", header=None)

# %%
#delete first row
m1 = m1.drop(index=0)
m2 = m2.drop(index=0)
m3 = m3.drop(index=0)

# %%
start_music = pd.read_csv("../UE_Motion_Capture/start_of_music.csv",delimiter="\t", header=None)

# %%
start_music[start_music[0]=='P3_M2'][1].item()
# Out:
# 5174.0

# %%
#Update TIme Values, to frames, to starting_time 
m1[0] = (m1[0]*100)+start_music[start_music[0]=='P3_M1'][1].item()
m2[0] = (m2[0]*100)+start_music[start_music[0]=='P3_M2'][1].item()
m3[0] = (m3[0]*100)+start_music[start_music[0]=='P3_M3'][1].item()

# %%
m2
# Out:
#               0           1
# 1   5359.179138  80.7495BPM
# 2   5433.482993  80.7495BPM
# 3   5507.786848  80.7495BPM
# 4   5582.090703  80.7495BPM
# 5   5658.716553  78.3026BPM
# 6   5734.181406  79.5072BPM
# 7   5809.646258  79.5072BPM
# 8   5885.111111  79.5072BPM
# 9   5958.253968  82.0313BPM
# 10  6032.557823  80.7495BPM
# 11  6109.183673  78.3026BPM
# 12  6184.648526  79.5072BPM
# 13  6257.791383  82.0313BPM
# 14  6332.095238  80.7495BPM
# 15  6406.399093  80.7495BPM
# 16  6480.702948  80.7495BPM
# 17  6555.006803  80.7495BPM
# 18  6629.310658  80.7495BPM
# 19  6703.614513  80.7495BPM
# 20  6777.918367  80.7495BPM
# 21  6854.544218  78.3026BPM
# 22  6932.331066  77.1339BPM

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.vlines(m2[0],0,500)
plt.vlines(m3[0],0,500)
plt.ylim([5, 30])
plt.xlim([0, 9800])
# Out:
# (0.0, 9800.0)

# %%
start = m1[0].min()
end = m1[0].max()

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 88.82941988586032

# %%
#ersten 5 Sekunden
start = m1[0].min()
end = m1[0].min()+500

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 84.0

# %% [markdown]
# # P3 - M1

# %%
m1_start = m1[0].min()
m1_end = m1[0].max()
print(m1_start)
print(m1_end)
# Out:
# 2724.3492063
# 4615.6145125

# %%
beats_in_m1_range = m1[(m1[0]>=m1_start) & (m1[0]<=m1_end)][0] 
steps_in_m1_range = steps.loc[(steps[0] >= m1_start) & (steps[0] <= m1_end)][0]

# %%
#all MUSIC M1
beats_in_m1_range.count()/((beats_in_m1_range.max()-beats_in_m1_range.min())/100/60)
# Out:
# 92.00189916749818

# %%
#all WALKING M1
steps_in_m1_range.count()/((steps_in_m1_range.max()-steps_in_m1_range.min())/100/60)
# Out:
# 91.35399673735726

# %%
after3W = steps_in_m1_range[steps_in_m1_range >= steps_in_m1_range.min()+300]

# %%
after3M = beats_in_m1_range[beats_in_m1_range >= beats_in_m1_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 93.24324324324324

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 92.7683246045788

# %%
from statistics import mean
mean(abs(x - y) for x, y in zip(beats_in_m1_range, steps_in_m1_range))
# Out:
# 45.95375770000006

# %%
from sklearn.metrics import mean_squared_error 
  
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(beats_in_m1_range,steps_in_m1_range)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p3.ipynb Cell 27 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.metrics import mean_squared_error
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> # Calculation of Mean Squared Error (MSE)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p3.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> mean_squared_error(beats_in_m1_range,steps_in_m1_range)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [29, 28]

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.ylim([5, 30])
plt.xlim([m1_start-20, m1_end+20])
# Out:
# (2704.3492063, 4635.6145125)

# %% [markdown]
# # P3 - M2

# %%
m2_start = m2[0].min()
m2_end = m2[0].max()
print(m2_start)
print(m2_end)
# Out:
# 5359.1791383
# 6932.3310658

# %%
beats_in_m2_range = m2[(m2[0]>=m2_start) & (m2[0]<=m2_end)][0] 
steps_in_m2_range = steps.loc[(steps[0] >= m2_start) & (steps[0] <= m2_end)][0]

# %%
#all MUSIC M1
beats_in_m2_range.count()/((beats_in_m2_range.max()-beats_in_m2_range.min())/100/60)
# Out:
# 83.90797970147102

# %%
#all WALKING M1
steps_in_m2_range.count()/((steps_in_m2_range.max()-steps_in_m2_range.min())/100/60)
# Out:
# 101.01010101010101

# %%
after3W = steps_in_m2_range[steps_in_m2_range >= steps_in_m2_range.min()+300]

# %%
after3M = beats_in_m2_range[beats_in_m2_range >= beats_in_m2_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 101.86757215619694

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 85.1312681660429

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
plt.vlines(m2[0],0,500)
plt.ylim([5, 30])
plt.xlim([m2_start-20, m2_end+20])
# Out:
# (5339.1791383, 6952.3310658)

# %% [markdown]
# # P3 - M3

# %%
m3_start = m3[0].min()
m3_end = m3[0].max()
print(m3_start)
print(m3_end)
# Out:
# 7632.4761905
# 9575.9863946

# %%
beats_in_m3_range = m3[(m3[0]>=m3_start) & (m3[0]<=m3_end)][0] 
steps_in_m3_range = steps.loc[(steps[0] >= m3_start) & (steps[0] <= m3_end)][0]

# %%
#all MUSIC M1
beats_in_m3_range.count()/((beats_in_m3_range.max()-beats_in_m3_range.min())/100/60)
# Out:
# 95.70312499909551

# %%
#all WALKING M1
steps_in_m3_range.count()/((steps_in_m3_range.max()-steps_in_m3_range.min())/100/60)
# Out:
# 96.46302250803859

# %%
after3W = steps_in_m3_range[steps_in_m3_range >= steps_in_m3_range.min()+300]

# %%
after3M = beats_in_m3_range[beats_in_m3_range >= beats_in_m3_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 97.02457956015525

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 96.38966104748079

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m3[0],0,500)
plt.ylim([5, 30])
plt.xlim([m3_start-20, m3_end+20])
# Out:
# (7612.4761905, 9595.9863946)
