# %%
#Import of used Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
p4 = pd.read_csv("../UE_Motion_Capture/data_export/walking_music_P4_pos.tsv",delimiter="\t",usecols=["RHeel_pos_Z","LHeel_pos_Z"])

# %%
plt.boxplot(p4["RHeel_pos_Z"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19a0f1d50d0>,
#   <matplotlib.lines.Line2D at 0x19a0f42e110>],
#  'caps': [<matplotlib.lines.Line2D at 0x19a0f42ef10>,
#   <matplotlib.lines.Line2D at 0x19a0f42fb10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19a0f42c550>],
#  'medians': [<matplotlib.lines.Line2D at 0x19a0f434650>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19a0f435190>],
#  'means': []}

# %%
#Calculation of right foot steps
Rsteps = []
frame = 0
bValley = False
for index, values in p4.iterrows():
    RValue = values["RHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if RValue < 70:
        bValley = False
        for i in range(1,80):
            if frame == 161:
                breakpoint()
            before = p4.loc[frame-i,"RHeel_pos_Z"]
            next = p4.loc[frame+i,"RHeel_pos_Z"]
            if (RValue <= before) and (RValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("R - ", frame, ": ", RValue)
            Rsteps.append([frame,RValue])
    frame += 1
# Out:
# R -  161 :  61.764
# R -  268 :  49.075
# R -  391 :  51.675
# R -  511 :  48.273
# R -  629 :  48.318
# R -  745 :  53.309
# R -  864 :  56.827
# R -  981 :  59.905
# R -  1099 :  56.811
# R -  1220 :  56.098
# R -  1337 :  51.361
# R -  1454 :  47.523
# R -  1571 :  51.104
# R -  1687 :  48.548
# R -  1802 :  50.829
# R -  1917 :  54.288
# R -  2032 :  56.71
# R -  2145 :  61.196
# R -  2260 :  57.563
# R -  2377 :  57.183
# R -  2490 :  53.194
# R -  2598 :  52.661
# R -  2708 :  51.083
# R -  2835 :  51.085
# R -  2978 :  48.215
# R -  3120 :  54.699
# R -  3255 :  56.862
# R -  3391 :  59.544
# R -  3525 :  60.018
# R -  3659 :  58.259
# R -  3793 :  55.969
# R -  3929 :  49.199
# R -  4063 :  49.409
# R -  4201 :  49.696
# R -  4335 :  48.804
# R -  4468 :  54.495
# R -  4599 :  56.331
# R -  4727 :  58.276
# R -  4858 :  59.638
# R -  4985 :  58.707
# R -  5112 :  55.84
# R -  5235 :  52.328
# R -  5361 :  49.398
# R -  5519 :  51.05
# R -  5683 :  46.646
# R -  5828 :  54.756
# R -  5974 :  57.019
# R -  6126 :  58.044
# R -  6271 :  59.723
# R -  6419 :  57.369
# R -  6572 :  57.098
# R -  6724 :  51.394
# R -  6871 :  50.349
# R -  7023 :  53.477
# R -  7173 :  47.666
# R -  7310 :  51.047
# R -  7451 :  56.438
# R -  7586 :  59.785
# R -  7716 :  59.197
# R -  7847 :  58.516
# R -  7975 :  57.039
# R -  8101 :  51.357
# R -  8231 :  49.025
# R -  8363 :  50.471
# R -  8494 :  46.218
# R -  8620 :  51.629
# R -  8754 :  54.471
# R -  8883 :  58.907
# R -  9012 :  58.813
# R -  9139 :  56.312
# R -  9269 :  55.361
# R -  9399 :  51.175
# R -  9529 :  49.654
# R -  9657 :  51.321
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 9740 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p4.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>     breakpoint()
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> before = p4.loc[frame-i,"RHeel_pos_Z"]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> next = p4.loc[frame+i,"RHeel_pos_Z"]
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> if (RValue <= before) and (RValue <= next):
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>     bValley = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4015, in DataFrame._get_value(self, index, col, takeable)
#    4009 engine = self.index._engine
#    4011 if not isinstance(self.index, MultiIndex):
#    4012     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4013     #  results if our categories are integers that dont match our codes
#    4014     # IntervalIndex: IntervalTree has no get_loc
# -> 4015     row = self.index.get_loc(index)
#    4016     return series._values[row]
#    4018 # For MultiIndex going through engine effectively restricts us to
#    4019 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: 9740

# %%
#Calculation of left foot steps
LSteps = []
frame = 0
for index, values in p4.iterrows():
    LValue = values["LHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if LValue < 70:
        for i in range(1,80):
            before = p4.loc[frame-i,"LHeel_pos_Z"]
            next = p4.loc[frame+i,"LHeel_pos_Z"]
            if (LValue <= before) and (LValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("L - ", frame, ": ", LValue)
            LSteps.append([frame,LValue])
    frame += 1
# Out:
# L -  206 :  60.482
# L -  330 :  54.845
# L -  451 :  54.107
# L -  571 :  51.313
# L -  689 :  53.973
# L -  805 :  60.714
# L -  921 :  63.345
# L -  1041 :  61.981
# L -  1161 :  63.257
# L -  1280 :  58.501
# L -  1396 :  53.647
# L -  1513 :  55.138
# L -  1629 :  52.662
# L -  1745 :  53.047
# L -  1860 :  56.717
# L -  1975 :  60.689
# L -  2088 :  64.406
# L -  2204 :  61.865
# L -  2319 :  61.153
# L -  2434 :  58.695
# L -  2546 :  56.075
# L -  2649 :  56.335
# L -  2769 :  56.475
# L -  2906 :  51.955
# L -  3052 :  53.673
# L -  3188 :  60.144
# L -  3325 :  63.025
# L -  3458 :  61.739
# L -  3592 :  63.17
# L -  3729 :  60.531
# L -  3862 :  56.809
# L -  3996 :  52.187
# L -  4133 :  54.97
# L -  4269 :  52.426
# L -  4404 :  54.69
# L -  4536 :  61.231
# L -  4664 :  62.388
# L -  4794 :  62.648
# L -  4922 :  60.94
# L -  5051 :  60.88
# L -  5175 :  58.461
# L -  5296 :  51.698
# L -  5441 :  55.267
# L -  5604 :  51.223
# L -  5758 :  53.357
# L -  5903 :  58.783
# L -  6050 :  60.976
# L -  6202 :  65.562
# L -  6345 :  62.771
# L -  6496 :  62.249
# L -  6648 :  58.279
# L -  6800 :  53.166
# L -  6948 :  55.962
# L -  7097 :  52.787
# L -  7243 :  52.136
# L -  7381 :  58.004
# L -  7519 :  61.214
# L -  7650 :  63.795
# L -  7781 :  63.006
# L -  7909 :  62.257
# L -  8038 :  57.6
# L -  8168 :  52.647
# L -  8298 :  54.567
# L -  8429 :  52.264
# L -  8557 :  52.508
# L -  8686 :  57.555
# L -  8819 :  61.991
# L -  8949 :  62.559
# L -  9077 :  61.668
# L -  9206 :  60.735
# L -  9336 :  56.908
# L -  9465 :  51.691
# L -  9593 :  56.556
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 9740 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p4.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> for i in range(1,80):
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a>     before = p4.loc[frame-i,"LHeel_pos_Z"]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a>     next = p4.loc[frame+i,"LHeel_pos_Z"]
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a>     if (LValue <= before) and (LValue <= next):
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a>         bValley = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4015, in DataFrame._get_value(self, index, col, takeable)
#    4009 engine = self.index._engine
#    4011 if not isinstance(self.index, MultiIndex):
#    4012     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4013     #  results if our categories are integers that dont match our codes
#    4014     # IntervalIndex: IntervalTree has no get_loc
# -> 4015     row = self.index.get_loc(index)
#    4016     return series._values[row]
#    4018 # For MultiIndex going through engine effectively restricts us to
#    4019 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: 9740

# %%
#Combination of steps
steps = LSteps + Rsteps
steps.sort()

# %%
steps = pd.DataFrame(steps)
steps
# Out:
#         0       1
# 0     161  61.764
# 1     206  60.482
# 2     268  49.075
# 3     330  54.845
# 4     391  51.675
# ..    ...     ...
# 142  9399  51.175
# 143  9465  51.691
# 144  9529  49.654
# 145  9593  56.556
# 146  9657  51.321
#
# [147 rows x 2 columns]

# %%
m1 = pd.read_csv("../UE_Motion_Capture/music/export_big_john.txt",delimiter="\t", header=None)
m2 = pd.read_csv("../UE_Motion_Capture/music/export_berlioz.txt",delimiter="\t", header=None)
m3 = pd.read_csv("../UE_Motion_Capture/music/export_wombats.txt",delimiter="\t", header=None)

# %%
#delete first row
m1 = m1.drop(index=0)
m2 = m2.drop(index=0)
m3 = m3.drop(index=0)

# %%
start_music = pd.read_csv("../UE_Motion_Capture/start_of_music.csv",delimiter="\t", header=None)

# %%
start_music[start_music[0]=='P4_M2'][1].item()
# Out:
# 5100.0

# %%
#Update TIme Values, to frames, to starting_time 
m1[0] = (m1[0]*100)+start_music[start_music[0]=='P4_M1'][1].item()
m2[0] = (m2[0]*100)+start_music[start_music[0]=='P4_M2'][1].item()
m3[0] = (m3[0]*100)+start_music[start_music[0]=='P4_M3'][1].item()

# %%
m2
# Out:
#               0           1
# 1   5285.179138  80.7495BPM
# 2   5359.482993  80.7495BPM
# 3   5433.786848  80.7495BPM
# 4   5508.090703  80.7495BPM
# 5   5584.716553  78.3026BPM
# 6   5660.181406  79.5072BPM
# 7   5735.646258  79.5072BPM
# 8   5811.111111  79.5072BPM
# 9   5884.253968  82.0313BPM
# 10  5958.557823  80.7495BPM
# 11  6035.183673  78.3026BPM
# 12  6110.648526  79.5072BPM
# 13  6183.791383  82.0313BPM
# 14  6258.095238  80.7495BPM
# 15  6332.399093  80.7495BPM
# 16  6406.702948  80.7495BPM
# 17  6481.006803  80.7495BPM
# 18  6555.310658  80.7495BPM
# 19  6629.614513  80.7495BPM
# 20  6703.918367  80.7495BPM
# 21  6780.544218  78.3026BPM
# 22  6858.331066  77.1339BPM

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.vlines(m2[0],0,500)
plt.vlines(m3[0],0,500)
plt.ylim([45, 70])
plt.xlim([0, 9800])
# Out:
# (0.0, 9800.0)

# %%
start = m1[0].min()
end = m1[0].max()

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 88.82941988586032

# %%
#ersten 5 Sekunden
start = m1[0].min()
end = m1[0].min()+500

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 84.0

# %%
m1_start = start_music[start_music[0]=='P4_M1'][1].item()
m1_end = start_music[start_music[0]=='P4_M2'][1].item()-500
print(m1_start)
print(m1_end)
# Out:
# 2500.0
# 4600.0

# %%
beats_in_m1_range = m1[(m1[0]>=m1_start) & (m1[0]<=m1_end)][0] 
steps_in_m1_range = steps.loc[(steps[0] >= m1_start) & (steps[0] <= m1_end)][0]

# %%
#all MUSIC M1
beats_in_m1_range.count()/((beats_in_m1_range.max()-beats_in_m1_range.min())/100/60)
# Out:
# 92.00189916749818

# %%
#all WALKING M1
steps_in_m1_range.count()/((m1_end-m1_start)/100)*60
# Out:
# 91.42857142857142

# %%
after3W = steps_in_m1_range[steps_in_m1_range >= steps_in_m1_range.min()+300]

# %%
after3M = beats_in_m1_range[beats_in_m1_range >= beats_in_m1_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 92.14412285883047

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 92.7683246045788

# %%
from statistics import mean
mean(abs(x - y) for x, y in zip(beats_in_m1_range, steps_in_m1_range))
# Out:
# 140.68652747931029

# %%
from sklearn.metrics import mean_squared_error 
  
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(beats_in_m1_range,steps_in_m1_range)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p4.ipynb Cell 26 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.metrics import mean_squared_error
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> # Calculation of Mean Squared Error (MSE)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p4.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> mean_squared_error(beats_in_m1_range,steps_in_m1_range)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [29, 32]

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.ylim([45, 70])
plt.xlim([m1_start-20, m1_end+20])
# Out:
# (2480.0, 4620.0)

# %% [markdown]
# # P4 - M2

# %%
m2_start = start_music[start_music[0]=='P4_M2'][1].item()
m2_end = start_music[start_music[0]=='P4_M3'][1].item()-500
print(m2_start)
print(m2_end)
# Out:
# 5100.0
# 6900.0

# %%
beats_in_m2_range = m2[(m2[0]>=m2_start) & (m2[0]<=m2_end)][0] 
steps_in_m2_range = steps.loc[(steps[0] >= m2_start) & (steps[0] <= m2_end)][0]

# %%
#all MUSIC M2
beats_in_m2_range.count()/((beats_in_m2_range.max()-beats_in_m2_range.min())/100/60)
# Out:
# 83.90797970147102

# %%
#all WALKING M2
steps_in_m2_range.count()/((m2_end-m2_start)/100)*60
# Out:
# 83.33333333333333

# %%
after3W = steps_in_m2_range[steps_in_m2_range >= steps_in_m2_range.min()+300]

# %%
after3M = beats_in_m2_range[beats_in_m2_range >= beats_in_m2_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 83.91608391608392

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 85.1312681660429

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
plt.vlines(m2[0],0,500)
plt.ylim([40, 70])
plt.xlim([m2_start-20, m2_end+20])
# Out:
# (5080.0, 6920.0)

# %% [markdown]
# # P4 - M3

# %%
m3_start = start_music[start_music[0]=='P4_M3'][1].item()
m3_end = m3[0].max()
print(m3_start)
print(m3_end)
# Out:
# 7400.0
# 9501.9863946

# %%
beats_in_m3_range = m3[(m3[0]>=m3_start) & (m3[0]<=m3_end)][0] 
steps_in_m3_range = steps.loc[(steps[0] >= m3_start) & (steps[0] <= m3_end)][0]

# %%
#all MUSIC M1
beats_in_m3_range.count()/((beats_in_m3_range.max()-beats_in_m3_range.min())/100/60)
# Out:
# 95.70312499909551

# %%
#all WALKING M3
steps_in_m3_range.count()/((m3_end-m3_start)/100/60)
# Out:
# 91.34217066925251

# %%
after3W = steps_in_m3_range[steps_in_m3_range >= steps_in_m3_range.min()+300]

# %%
after3M = beats_in_m3_range[beats_in_m3_range >= beats_in_m3_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 96.19952494061758

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 96.38966104748079

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m3[0],0,500)
plt.ylim([40, 90])
plt.xlim([m3_start-20, m3_end+20])
# Out:
# (7380.0, 9521.9863946)
