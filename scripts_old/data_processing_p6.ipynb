# %%
#Import of used Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
p4 = pd.read_csv("../UE_Motion_Capture/data_export/walking_music_P6_pos.tsv",delimiter="\t",usecols=["RHeel_pos_Z","LHeel_pos_Z"])

# %%
plt.boxplot(p4["RHeel_pos_Z"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20a84653610>,
#   <matplotlib.lines.Line2D at 0x20a84664410>],
#  'caps': [<matplotlib.lines.Line2D at 0x20a846651d0>,
#   <matplotlib.lines.Line2D at 0x20a84665d90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20a8462ccd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20a84666950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20a84667490>],
#  'means': []}

# %%
#Calculation of right foot steps
Rsteps = []
frame = 0
bValley = False
for index, values in p4.iterrows():
    RValue = values["RHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if RValue < 70:
        bValley = False
        for i in range(1,80):
            if frame == 161:
                breakpoint()
            before = p4.loc[frame-i,"RHeel_pos_Z"]
            next = p4.loc[frame+i,"RHeel_pos_Z"]
            if (RValue <= before) and (RValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("R - ", frame, ": ", RValue)
            Rsteps.append([frame,RValue])
    frame += 1
# Out:
# R -  247 :  45.453
# R -  362 :  47.547
# R -  474 :  43.371
# R -  584 :  43.452
# R -  692 :  48.574
# R -  800 :  53.226
# R -  906 :  54.557
# R -  1015 :  52.042
# R -  1125 :  51.085
# R -  1235 :  47.269
# R -  1343 :  45.704
# R -  1450 :  46.16
# R -  1557 :  43.052
# R -  1667 :  45.736
# R -  1773 :  49.74
# R -  1882 :  54.052
# R -  1990 :  53.354
# R -  2099 :  54.65
# R -  2205 :  50.362
# R -  2317 :  46.632
# R -  2423 :  47.407
# R -  2530 :  45.372
# R -  2645 :  40.551
# R -  2764 :  46.246
# R -  2884 :  52.486
# R -  3004 :  54.367
# R -  3123 :  51.903
# R -  3250 :  52.062
# R -  3380 :  48.295
# R -  3506 :  43.737
# R -  3633 :  46.55
# R -  3763 :  43.44
# R -  3885 :  42.377
# R -  4006 :  46.553
# R -  4137 :  50.264
# R -  4261 :  53.819
# R -  4389 :  48.823
# R -  4524 :  50.897
# R -  4655 :  47.064
# R -  4781 :  43.524
# R -  4899 :  46.249
# R -  5021 :  43.113
# R -  5136 :  42.702
# R -  5259 :  47.199
# R -  5394 :  52.408
# R -  5514 :  57.603
# R -  5612 :  55.873
# R -  5709 :  55.311
# R -  5800 :  52.775
# R -  5894 :  50.074
# R -  5981 :  45.811
# R -  6066 :  48.503
# R -  6161 :  47.469
# R -  6248 :  44.195
# R -  6346 :  48.663
# R -  6443 :  52.268
# R -  6541 :  57.912
# R -  6638 :  52.936
# R -  6734 :  50.651
# R -  6831 :  54.923
# R -  6917 :  50.45
# R -  7025 :  45.78
# R -  7133 :  48.129
# R -  7241 :  46.145
# R -  7351 :  42.58
# R -  7460 :  46.262
# R -  7582 :  51.077
# R -  7699 :  52.957
# R -  7817 :  50.825
# R -  7934 :  51.342
# R -  8054 :  47.56
# R -  8177 :  43.538
# R -  8299 :  43.83
# R -  8421 :  41.185
# R -  8542 :  42.503
# R -  8671 :  49.802
# R -  8802 :  53.528
# R -  8931 :  50.893
# R -  9062 :  51.431
# R -  9191 :  48.089
# R -  9323 :  44.458
# R -  9453 :  45.898
# R -  9580 :  43.304

# %%
#Calculation of left foot steps
LSteps = []
frame = 0
for index, values in p4.iterrows():
    LValue = values["LHeel_pos_Z"]
    if frame < 150:
        frame += 1
        continue
    if LValue < 70:
        for i in range(1,80):
            before = p4.loc[frame-i,"LHeel_pos_Z"]
            next = p4.loc[frame+i,"LHeel_pos_Z"]
            if (LValue <= before) and (LValue <= next):
                bValley = True
            else:
                bValley = False
                break
        if bValley:
            print("L - ", frame, ": ", LValue)
            LSteps.append([frame,LValue])
    frame += 1
# Out:
# L -  177 :  48.81
# L -  302 :  43.609
# L -  415 :  44.588
# L -  526 :  40.111
# L -  636 :  46.819
# L -  744 :  52.637
# L -  849 :  53.843
# L -  959 :  53.56
# L -  1067 :  52.652
# L -  1178 :  49.373
# L -  1286 :  45.993
# L -  1394 :  47.027
# L -  1502 :  44.648
# L -  1609 :  43.48
# L -  1717 :  50.193
# L -  1824 :  53.439
# L -  1932 :  54.013
# L -  2043 :  53.891
# L -  2150 :  51.855
# L -  2258 :  49.368
# L -  2366 :  43.234
# L -  2475 :  46.585
# L -  2582 :  42.188
# L -  2698 :  44.029
# L -  2821 :  51.796
# L -  2940 :  51.802
# L -  3059 :  51.615
# L -  3180 :  51.797
# L -  3309 :  52.467
# L -  3438 :  48.129
# L -  3565 :  40.981
# L -  3693 :  44.097
# L -  3821 :  40.238
# L -  3942 :  44.401
# L -  4068 :  50.907
# L -  4192 :  51.31
# L -  4321 :  54.502
# L -  4450 :  50.018
# L -  4586 :  52.06
# L -  4717 :  46.74
# L -  4837 :  43.436
# L -  4958 :  43.646
# L -  5078 :  41.013
# L -  5194 :  46.186
# L -  5325 :  53.035
# L -  5455 :  54.85
# L -  5563 :  55.006
# L -  5660 :  54.166
# L -  5754 :  54.211
# L -  5850 :  50.768
# L -  5937 :  48.709
# L -  6021 :  48.357
# L -  6114 :  44.887
# L -  6203 :  43.384
# L -  6298 :  46.073
# L -  6394 :  52.86
# L -  6492 :  54.968
# L -  6587 :  54.961
# L -  6684 :  53.243
# L -  6779 :  55.805
# L -  6873 :  54.449
# L -  6967 :  49.932
# L -  7077 :  43.174
# L -  7185 :  45.836
# L -  7292 :  42.942
# L -  7402 :  45.788
# L -  7517 :  50.199
# L -  7636 :  50.648
# L -  7754 :  53.399
# L -  7873 :  52.06
# L -  7988 :  48.934
# L -  8110 :  45.98
# L -  8235 :  46.199
# L -  8356 :  43.703
# L -  8478 :  41.978
# L -  8605 :  48.7
# L -  8733 :  50.83
# L -  8866 :  53.022
# L -  8993 :  50.785
# L -  9124 :  50.799
# L -  9252 :  47.111
# L -  9381 :  41.132
# L -  9515 :  45.894

# %%
#Combination of steps
steps = LSteps + Rsteps
steps.sort()

# %%
steps = pd.DataFrame(steps)
steps
# Out:
#         0       1
# 0     177  48.810
# 1     247  45.453
# 2     302  43.609
# 3     362  47.547
# 4     415  44.588
# ..    ...     ...
# 161  9323  44.458
# 162  9381  41.132
# 163  9453  45.898
# 164  9515  45.894
# 165  9580  43.304
#
# [166 rows x 2 columns]

# %%
m1 = pd.read_csv("../UE_Motion_Capture/music/export_big_john.txt",delimiter="\t", header=None)
m2 = pd.read_csv("../UE_Motion_Capture/music/export_berlioz.txt",delimiter="\t", header=None)
m3 = pd.read_csv("../UE_Motion_Capture/music/export_wombats.txt",delimiter="\t", header=None)

# %%
#delete first row
m1 = m1.drop(index=0)
m2 = m2.drop(index=0)
m3 = m3.drop(index=0)

# %%
start_music = pd.read_csv("../UE_Motion_Capture/start_of_music.csv",delimiter="\t", header=None)

# %%
start_music[start_music[0]=='P6_M2'][1].item()
# Out:
# 5120.0

# %%
#Update TIme Values, to frames, to starting_time 
m1[0] = (m1[0]*100)+start_music[start_music[0]=='P6_M1'][1].item()
m2[0] = (m2[0]*100)+start_music[start_music[0]=='P6_M2'][1].item()
m3[0] = (m3[0]*100)+start_music[start_music[0]=='P6_M3'][1].item()

# %%
m2
# Out:
#               0           1
# 1   5305.179138  80.7495BPM
# 2   5379.482993  80.7495BPM
# 3   5453.786848  80.7495BPM
# 4   5528.090703  80.7495BPM
# 5   5604.716553  78.3026BPM
# 6   5680.181406  79.5072BPM
# 7   5755.646258  79.5072BPM
# 8   5831.111111  79.5072BPM
# 9   5904.253968  82.0313BPM
# 10  5978.557823  80.7495BPM
# 11  6055.183673  78.3026BPM
# 12  6130.648526  79.5072BPM
# 13  6203.791383  82.0313BPM
# 14  6278.095238  80.7495BPM
# 15  6352.399093  80.7495BPM
# 16  6426.702948  80.7495BPM
# 17  6501.006803  80.7495BPM
# 18  6575.310658  80.7495BPM
# 19  6649.614513  80.7495BPM
# 20  6723.918367  80.7495BPM
# 21  6800.544218  78.3026BPM
# 22  6878.331066  77.1339BPM

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.vlines(m2[0],0,500)
plt.vlines(m3[0],0,500)
plt.ylim([35, 60])
plt.xlim([0, 9800])
# Out:
# (0.0, 9800.0)

# %%
start_music[start_music[0]=='P6_M2'][1].item()
# Out:
# 5120.0

# %%
start = start_music[start_music[0]=='P6_M1'][1].item()
end = start_music[start_music[0]=='P6_M2'][1].item()-500

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 97.14285714285715

# %%
#ersten 5 Sekunden
start = m1[0].min()
end = m1[0].min()+500

steps.loc[(steps[0] >= start) & (steps[0] <= end)].count()[0]/(((end-start)/100)/60)
# Out:
# 96.0

# %% [markdown]
# # P6 - M1

# %%
m1_start = start_music[start_music[0]=='P6_M1'][1].item()
m1_end = start_music[start_music[0]=='P6_M2'][1].item()-500
print(m1_start)
print(m1_end)
# Out:
# 2520.0
# 4620.0

# %%
beats_in_m1_range = m1[(m1[0]>=m1_start) & (m1[0]<=m1_end)][0] 
steps_in_m1_range = steps.loc[(steps[0] >= m1_start) & (steps[0] <= m1_end)][0]

# %%
steps_in_m1_range.count()
# Out:
# 30

# %%
steps_in_m1_range.count()/((beats_in_m1_range.max()-beats_in_m1_range.min())/100/60)
# Out:
# 107.86429557568752

# %%
beats_in_m1_range.max()-beats_in_m1_range.min()
# Out:
# 1891.2653062000004

# %%
#all MUSIC M1
beats_in_m1_range.count()/((beats_in_m1_range.max()-beats_in_m1_range.min())/100/60)
# Out:
# 92.00189916749818

# %%
#all WALKING M1
steps_in_m1_range.count()/((m1_end-m1_start)/100)*60
# Out:
# 97.14285714285714

# %%
after3W = steps_in_m1_range[steps_in_m1_range >= steps_in_m1_range.min()+300]

# %%
after3M = beats_in_m1_range[beats_in_m1_range >= beats_in_m1_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 98.70740305522914

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 92.7683246045788

# %%
from statistics import mean
mean(abs(x - y) for x, y in zip(beats_in_m1_range, steps_in_m1_range))
# Out:
# 55.004456948275845

# %%
from sklearn.metrics import mean_squared_error 
  
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(beats_in_m1_range,steps_in_m1_range)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\andre\Documents\UNI\Master_Digital_Humanities\S1_WS2023\UE_Motion_Capture\data_processing_p6.ipynb Cell 27 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p6.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.metrics import mean_squared_error
#       <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p6.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> # Calculation of Mean Squared Error (MSE)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andre/Documents/UNI/Master_Digital_Humanities/S1_WS2023/UE_Motion_Capture/data_processing_p6.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> mean_squared_error(beats_in_m1_range,steps_in_m1_range)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:99, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      65 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      66     """Check that y_true and y_pred belong to the same regression task.
#      67
#      68     Parameters
#    (...)
#      97         correct keyword.
#      98     """
# ---> 99     check_consistent_length(y_true, y_pred)
#     100     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [29, 30]

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m1[0],0,500)
plt.ylim([35, 60])
plt.xlim([m1_start-20, m1_end+20])
# Out:
# (2650.3492063, 4581.6145125)

# %% [markdown]
# # P6 - M2

# %%
m2_start = start_music[start_music[0]=='P6_M2'][1].item()
m2_end = start_music[start_music[0]=='P6_M3'][1].item()-500
print(m2_start)
print(m2_end)
# Out:
# 5120.0
# 6920.0

# %%
beats_in_m2_range = m2[(m2[0]>=m2_start) & (m2[0]<=m2_end)][0] 
steps_in_m2_range = steps.loc[(steps[0] >= m2_start) & (steps[0] <= m2_end)][0]

# %%
#all MUSIC M1
beats_in_m2_range.count()/((beats_in_m2_range.max()-beats_in_m2_range.min())/100/60)
# Out:
# 83.90797970147102

# %%
#all WALKING M2
steps_in_m1_range.count()/((m2_end-m2_start)/100)*60
# Out:
# 113.33333333333333

# %%
first3W = steps_in_m2_range[steps_in_m2_range <= steps_in_m2_range.min()+300]

# %%
first3W.count()/((first3W.max()-first3W.min())/100/60)
# Out:
# 116.27906976744185

# %%
first3M = beats_in_m2_range[beats_in_m2_range <= beats_in_m2_range.min()+300]

# %%
first3M.count()/((first3M.max()-first3M.min())/100/60)
# Out:
# 100.15443312816204

# %%
after3W = steps_in_m2_range[steps_in_m2_range >= steps_in_m2_range.min()+300]

# %%
after3M = beats_in_m2_range[beats_in_m2_range >= beats_in_m2_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 131.32694938440494

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 85.1312681660429

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
plt.vlines(m2[0],0,500)
plt.ylim([35, 65])
plt.xlim([m2_start-20, m2_end+20])
# Out:
# (5100.0, 6940.0)

# %% [markdown]
# # P6 - M3

# %%
m3_start = start_music[start_music[0]=='P6_M3'][1].item()
m3_end = m3[0].max()
print(m3_start)
print(m3_end)
# Out:
# 7420.0
# 9521.9863946

# %%
beats_in_m3_range = m3[(m3[0]>=m3_start) & (m3[0]<=m3_end)][0] 
steps_in_m3_range = steps.loc[(steps[0] >= m3_start) & (steps[0] <= m3_end)][0]

# %%
#all MUSIC M3
beats_in_m3_range.count()/((beats_in_m3_range.max()-beats_in_m3_range.min())/100/60)
# Out:
# 95.70312499909551

# %%
#all WALKING M3
steps_in_m3_range.count()/((m3_end-m3_start)/100/60)
# Out:
# 97.0510563360808

# %%
after3W = steps_in_m3_range[steps_in_m3_range >= steps_in_m3_range.min()+300]

# %%
after3M = beats_in_m3_range[beats_in_m3_range >= beats_in_m3_range.min()+300]

# %%
#after3 WALKING
after3W.count()/((after3W.max()-after3W.min())/100/60)
# Out:
# 98.9399293286219

# %%
#after3 music
after3M.count()/((after3M.max()-after3M.min())/100/60)
# Out:
# 96.38966104748079

# %%
plt.figure(figsize=(20,3))
plt.plot(p4)
plt.plot(steps[0],steps[1],'bo')
#plt.plot(m1[0],m1[3],'x')
plt.vlines(m3[0],0,500)
plt.ylim([35, 60])
plt.xlim([m3_start-20, m3_end+20])
# Out:
# (7400.0, 9541.9863946)
